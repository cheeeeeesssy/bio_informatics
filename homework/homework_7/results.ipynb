# %% [markdown]
# **Задание 1**

# %% [markdown]
# Были выбраны 3 последовательности S-белка SARS-CoV-2, представленные в файле */task_1/all_proteins.fasta*. К тем же файлам была добавлена последовательность с семинара (перед этим перевели ее из нуклеотидной последовательности в аминокислотную)

# %% [markdown]
# Последовательности были выровнены при помощи множественного выравнивания MUSCLE, и построено их филогенетическоге дерево:

# %% [markdown]
# ![изображение.png](attachment:89f32651-4bbf-4fd8-9b13-a679b36bd62a.png)

# %% [markdown]
# **Вывод:** lcl|ORF1 - последовательность с семинара, переведенная в аминокислотную последовательность, оказалась эволюционно наиболее близкой к YP_009724390.1
# YP_009047204.1 S [organism=Middle East respiratory syndrome-related coronavirus] является наиболее эволюционно далеким от остальных последовательностей, что может быть связано с территориальной причиной

# %% [markdown]
# **Задание 2**

# %% [markdown]
# Был скачан датасет ортологов для <a href="https://www.ncbi.nlm.nih.gov/gene/14254594" target="_blank">S spike protein [ Middle East respiratory syndrome-related coronavirus ]</a> при помощи команды
# datasets download gene accession NC_019843.3 --ortholog all

# %% [markdown]
# Полученные ортологи можно найти в файле */task_2/orthologs.fasta*
# По нимм построено филогенетическое дерево:

# %% [markdown]
# ![изображение.png](attachment:dc0fccfd-020b-4455-aa61-2678206acb82.png)

# %% [markdown]
# **Вывод:** наиболее эволюционно близкими являются YP_009047210.1 M [organism=Middle East respiratory syndrome-related coronavirus] и YP_009047202.1 orf1ab [organism=Middle East respiratory syndrome-related coronavirus], что, возможно, связано не с эволюционной близостью, а со слиянием генов (в результате белок M содержит домены, произошедшие от orf1ab); YP_009047209.1 E [organism=Middle East respiratory syndrome-related coronavirus] и YP_009047211.1 N [organism=Middle East respiratory syndrome-related coronavirus] могут быть ошибочно эволюционно близкими (белок E очень мал), либо это объясняется их близкими функциями - оба белка являются структурными
# белок YP_009047204.1 S является наиболее эволюционно близким к белку YP_009047210.1 M, что связано с их свхожими функциями: S-белок отвечает за связывание с клетками-хозяевами, а M-белок способствует сборке и высвобождению вируса (оба белка структурные))
# Эволюционная дальность белков S и M от белков E и N может быть связана с небольшими функциональными различиями: S- и M-белки больше отвечают за адаптацию к хозяину, в то время, как белки E и N участвуют в сборке вируса и отвечают за упаковку генома
